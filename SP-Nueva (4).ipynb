# %% [markdown]
# # Situacion Problema
# ## Federico Garcia Gomez A01177352

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import numpy as nms
from sklearn import linear_model

# %%
# %ls datasets_new/
# Out:
# 'Forbes Worlds Billionaires.csv'

# %% [markdown]
# # Introduccion
# ## Descripcion de Variables de Interes
# ## Mis Variables de interes son 'Gender', 'Age', 'Continent', 'Net Worth'
# * 'Gender' (Categorica) Esta variable nos interesa para dividir los supeheroes y ver si el comportamiento de su peso y altura tiene algo de relacion con el genero
# * 'Age' (Numerica) Esta variable es de interes ya que describe la edad actual del billonario.
# * 'Continent' (Categorica) Esta variable es de interes ya que describe el continente en el cual nacio el billonario.
# * 'Net Woth' (Numerica) Esta variable nos interesa gracias a que podremos observar el calor actual en activos de la persona.

# %%
df = pd.read_csv('datasets_new/Forbes Worlds Billionaires.csv')
df.head()
# Out:
#    Rank             Name   Age              Source                 Industry  \
# 0     1       Jeff Bezos  54.0              Amazon               Technology
# 1     2       Bill Gates  62.0           Microsoft               Technology
# 2     3   Warren Buffett  87.0  Berkshire Hathaway  Finance and Investments
# 3     4  Bernard Arnault  69.0                LVMH         Fashion & Retail
# 4     5  Mark Zuckerberg  33.0            Facebook               Technology
#
#   Gender      Continent        Country Headquarters       State  Net Worth  \
# 0   Male  North America  United States           WA  Washington      112.0
# 1   Male  North America  United States           WA  Washington       90.0
# 2   Male  North America  United States           NE    Nebraska       84.0
# 3   Male         Europe         France          NaN         NaN       72.0
# 4   Male  North America  United States           CA  California       71.0
#
#                                                Title
# 0                        CEO and Founder, Amazon.com
# 1         Cofounder, Bill & Melinda Gates Foundation
# 2                            CEO, Berkshire Hathaway
# 3  Chairman and CEO, LVMH Moet Hennessy Louis Vui...
# 4              Cofounder, Chairman and CEO, Facebook

# %% [markdown]
# ## Pregunta 1
#  ¿De que continente son los billonarios con valor neto mas alto Hombres y Mujeres? dentro del top 100 billonarios del mundo

# %%
my_pivot = pd.pivot_table(df,
                          index = ['Continent'],
                          values = ['Net Worth'],
                          #aggfunc = ['std','sum','mean','median']
                          aggfunc = ['max','mean'],
                          columns = 'Gender',
                          margins = True
                         )
my_pivot
# Out:
#                     max                     mean
#               Net Worth                Net Worth
# Gender           Female   Male    All     Female       Male        All
# Continent
# Africa              NaN   14.1   14.1        NaN  14.100000  14.100000
# Asia               21.9   45.3   45.3  21.900000  20.832432  20.860526
# Europe             42.2   72.0   72.0  27.666667  25.194737  25.531818
# North America      46.0  112.0  112.0  26.075000  39.822581  38.251429
# Oceania            17.4    NaN   17.4  17.400000        NaN  17.400000
# South America      16.3   27.4   27.4  16.300000  25.450000  22.400000
# All                46.0  112.0  112.0  24.290000  28.322222  27.919000

# %% [markdown]
# ## Resultado
#  El continente con el hombre y muejer con el valor neto mas alto es America del Norte

# %% [markdown]
# ## Pregunta 2
# ¿De que Industria son los billonarios con valor neto mas alto Hombres y Mujeres? dentro del top 100 billonarios del mundo

# %%
my_pivot = pd.pivot_table(df,
                          index = ['Industry'],
                          values = ['Net Worth'],
                          #aggfunc = ['std','sum','mean','median']
                          aggfunc = ['max','mean'],
                          columns = 'Gender',
                          margins = True
                         )
my_pivot
# Out:
#              max                    mean
#        Net Worth               Net Worth
# Gender    Female   Male    All    Female       Male        All
# Age
# 31.0         NaN   15.9   15.9       NaN  15.900000  15.900000
# 33.0         NaN   71.0   71.0       NaN  71.000000  71.000000
# 36.0        21.9    NaN   21.9     21.90        NaN  21.900000
# 44.0         NaN   48.8   48.8       NaN  48.150000  48.150000
# 46.0         NaN   45.3   45.3       NaN  22.740000  22.740000
# 47.0         NaN   14.7   14.7       NaN  14.700000  14.700000
# 48.0         NaN   18.2   18.2       NaN  18.200000  18.200000
# 51.0         NaN   22.0   22.0       NaN  22.000000  22.000000
# 52.0         NaN   18.7   18.7       NaN  18.700000  18.700000
# 53.0         NaN   39.0   39.0       NaN  23.433333  23.433333
# 54.0        18.8  112.0  112.0     18.80  63.650000  48.700000
# 55.0        25.0    NaN   25.0     25.00        NaN  25.000000
# 56.0        15.9    NaN   15.9     15.90        NaN  15.900000
# 57.0         NaN   15.9   15.9       NaN  15.900000  15.900000
# 59.0         NaN   30.3   30.3       NaN  30.300000  30.300000
# 60.0         NaN   40.1   40.1       NaN  22.750000  22.750000
# 61.0         NaN   38.4   38.4       NaN  28.750000  28.750000
# 62.0         NaN   90.0   90.0       NaN  54.000000  54.000000
# 63.0        15.8   30.0   30.0     15.80  30.000000  22.900000
# 64.0        42.2   17.3   42.2     29.80  17.300000  25.633333
# 65.0         NaN   21.7   21.7       NaN  18.033333  18.033333
# 66.0         NaN   16.7   16.7       NaN  16.700000  16.700000
# 67.0         NaN   20.2   20.2       NaN  18.366667  18.366667
# 68.0        46.0   17.7   46.0     46.00  17.700000  31.850000
# 69.0         NaN   72.0   72.0       NaN  45.966667  45.966667
# 70.0         NaN   16.8   16.8       NaN  16.800000  16.800000
# 72.0         NaN   18.8   18.8       NaN  16.250000  16.250000
# 73.0         NaN   58.5   58.5       NaN  33.180000  33.180000
# 75.0        16.3   20.1   20.1     16.30  20.100000  18.200000
# 76.0         NaN   50.0   50.0       NaN  34.300000  34.300000
# 77.0         NaN   60.0   60.0       NaN  38.700000  38.700000
# 78.0        23.6   67.1   67.1     23.60  29.400000  28.433333
# 79.0         NaN   23.5   23.5       NaN  21.750000  21.750000
# 80.0         NaN   29.6   29.6       NaN  22.450000  22.450000
# 81.0         NaN   70.0   70.0       NaN  48.500000  48.500000
# 82.0         NaN   60.0   60.0       NaN  30.400000  30.400000
# 84.0         NaN   38.5   38.5       NaN  38.500000  38.500000
# 85.0         NaN   16.3   16.3       NaN  16.300000  16.300000
# 86.0         NaN   15.0   15.0       NaN  15.000000  15.000000
# 87.0         NaN   84.0   84.0       NaN  84.000000  84.000000
# 88.0         NaN   20.1   20.1       NaN  18.950000  18.950000
# 89.0         NaN   34.9   34.9       NaN  34.900000  34.900000
# 90.0         NaN   30.3   30.3       NaN  30.300000  30.300000
# 92.0         NaN   22.6   22.6       NaN  22.600000  22.600000
# 93.0         NaN   20.0   20.0       NaN  20.000000  20.000000
# 94.0         NaN   14.8   14.8       NaN  14.800000  14.800000
# All         46.0  112.0  112.0     24.29  28.706897  28.251546

# %% [markdown]
# ## Resultado
# La industria con el hombre con el valor neto mas alto es la de 'Tecnology' con 112 billones de dolares, y la industria con la mujer con el valor neto mas alto es la de 'Fashion & Retail' con 46 billones de dolares

# %% [markdown]
# # Pregunta 3: ¿Cual es la tendencia en el valor neto de los top 100 billonarios del mundo?

# %%
sns.histplot(df['Net Worth'],
             kde = False,
            bins = 10).set_title('Histogram of Net Worth')
# Out:
# Text(0.5, 1.0, 'Histogram of Net Worth')

# %% [markdown]
# # Resultado
# ## -La mayoria de los billonarios dentro del top 100 del mundo tienen un valor neto menor a los 30 billones de dolares.

# %% [markdown]
# # Pregunta 4 ¿Existe alguna correlacion entre el net worth y la edad?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.lmplot (x = 'Net Worth',
            y= 'Age',
            data = df,
            fit_reg = False,
          
            
           )
plt.title('Scatter Plot of Net Worth vs Age', fontsize = 17)
plt.xticks(fontsize = 15)
plt.show()

# %% [markdown]
# ## Resultado

# %% [markdown]
# El net worth y la edad entre los dos generos no tienen correlacion como se puede observar ya que los datos se comportan muy dispersados y no se observa una tendencia.

# %% [markdown]
# ## Pregunta 5: ¿Se tienen valores atipicos en el valor neto o la edad de los billonarios?

# %%
sns.boxplot( x =df['Net Worth'],
           whis = (0,100),
           y = df['Gender']
           ).set_title('box plot of Net Worth')
# Out:
# Text(0.5, 1.0, 'box plot of Net Worth')

# %%
sns.boxplot( x =df['Age'],
           whis = (0,100),
           y = df['Gender']
           ).set_title('box plot of Weight')
# Out:
# Text(0.5, 1.0, 'box plot of Weight')

# %% [markdown]
# ## Resultados
# Se puede observar que no se encontraron valores atipicos ni en el valor neto asi como en la edad de los top 100 billonarios del mundo.

# %% [markdown]
# ## Conclusiones y Observaciones
# * No se pudo observar correlacion entre las variables de Edad y valor neto
# * Continente con hombre y la mujero con el valor neto mas alto es America del Norte. Mujer: 46.0 billones. Hombre: 112 billones.
# * La industria con el hombre con el valor neto mas alto es la de 'Tecnology', y la industria con la mujer con el valor neto mas alto es la de 'Fashion & Retail'
# * En minimos de altura y peso 17 distintas editoriales dieron los mismos valores de negativo 99.99.
# * No se tienen datos atipicos en graficas de box plot ni en edad asi como en el valor neto de ningun genero.

# %% [markdown]
# ## Clase 1 - Introduccion a Python

# %%
print('hola')
# Out:
# hola

# %% [markdown]
# ## Cargando Librerias

# %%
import numpy as np

# %%
x = 50 
numeros_aleatorios = np.random.rand(x)
numeros_aleatorios
# Out:
# array([0.97106269, 0.48607331, 0.3319384 , 0.06234465, 0.0689243 ,
#        0.55252479, 0.89325129, 0.42033777, 0.94485338, 0.53936509,
#        0.88151316, 0.87201799, 0.70368103, 0.27713706, 0.38184698,
#        0.65145873, 0.65041665, 0.2614699 , 0.34862627, 0.38261218,
#        0.88210943, 0.58300049, 0.36205182, 0.25102782, 0.8486718 ,
#        0.02625665, 0.02529896, 0.88807082, 0.84175621, 0.31357846,
#        0.02493969, 0.04439569, 0.13466236, 0.31567366, 0.91376189,
#        0.98124165, 0.70172763, 0.33235471, 0.06403605, 0.87257569,
#        0.6102577 , 0.70641978, 0.8933821 , 0.36240733, 0.79357928,
#        0.80212605, 0.27084564, 0.2416826 , 0.01852835, 0.2183182 ])

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          mic.xlsx

# %% [markdown]
# ## Tipos de Datos

# %%
import math

# %%
type(4)
# Out:
# int

# %%
type(4.0)
# Out:
# float

# %%
type(-3)
# Out:
# int

# %%
x = 'nombre1'
x
# Out:
# 'nombre1'

# %%
type(x)
# Out:
# str

# %%
numbers = [1,2,3,4,5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type(numbers)
# Out:
# list

# %%
sum_ = sum(numbers)
sum_
# Out:
# 15

# %%
length = len(numbers)
length
# Out:
# 5

# %%
promedio = sum_/length
promedio
# Out:
# 3.0

# %%
type(3/5)
# Out:
# float

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
type(math.pi)
# Out:
# float

# %%
type('math.pi')
# Out:
# str

# %%
numbers = [math.pi, 3/5, 4.0, 'nombre', True]
numbers
# Out:
# [3.141592653589793, 0.6, 4.0, 'nombre', True]

# %%
type(True)
# Out:
# bool

# %%
type('True')
# Out:
# str

# %%
print(None)
# Out:
# None

# %%
type(None)
# Out:
# NoneType

# %%
x = 16
y = 8
if x < y:
    print('{} es menor que {}'.format(x,y))
else:
    print(x, 'es mayor que', y)
# Out:
# 16 es mayor que 8

# %%
unalista =[True, 6<5, 1==3, None is None]
unalista
# Out:
# [True, False, False, True]

# %% [markdown]
# ## El uso de for loop

# %%
for element in unalista:
    print(element,'\t',type(element))
# Out:
# True 	 <class 'bool'>
# False 	 <class 'bool'>
# False 	 <class 'bool'>
# True 	 <class 'bool'>

# %% [markdown]
# # lista

# %%
unaLista = ['first','second','third','fourth','fifth','sixth']
unaLista
# Out:
# ['first', 'second', 'third', 'fourth', 'fifth', 'sixth']

# %%
#unaLista.sort()
#unaLista

# %%
unaLista[:1]
# Out:
# ['first']

# %%
unaLista[:]
# Out:
# ['first', 'second', 'third', 'fourth', 'fifth', 'sixth']

# %%
unaLista[1:3] #sin incluir elemento en la psicion 3
# Out:
# ['second', 'third']

# %%
unaLista[5]
# Out:
# 'sixth'

# %%
unaLista[-1]
# Out:
# 'sixth'

# %%
unaLista[-4:-1] #sin incluir el elemento en la posicion -1
# Out:
# ['third', 'fourth', 'fifth']
